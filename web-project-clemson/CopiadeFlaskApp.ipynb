# %% [markdown]
# # Flask App

# %% [markdown]
# ## Clone Flask App (Github/Gitlab)

# %%
# !git clone https://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@github.com/ManeAI31416/web-project-clemson.git
# Out:
# Cloning into 'web-project-clemson'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 2), reused 12 (delta 2), pack-reused 0
# Receiving objects: 100% (12/12), 4.90 KiB | 4.90 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# !cp -r /content/web-project-clemson/static/ /content/static/
# !cp -r /content/web-project-clemson/templates/ /content/templates/

# %% [markdown]
# ## Colab localhost

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))
# Out:
# https://64z8lruszfg-496ff2e9c6d22116-5000-colab.googleusercontent.com/

# %% [markdown]
# ## Basic

# %%
from flask import Flask, render_template, request
app = Flask(__name__, template_folder='')

@app.route('/')
def home():
    return render_template('index.html')
if __name__ == '__main__':
    app.run()

# %%
## Unicamente si no se clono es para pruebas

# !mkdir templates
# !mkdir static

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### dependencias

# %%
# !pip install faster_whisper flask -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 43.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.3/192.3 MB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 97.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.2 MB/s eta 0:00:00

# %%
# !pip install langchain -q
# !pip install langchain_experimental -q
# !pip install langchain-huggingface -q
# !pip install huggingface_hub -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.4 MB/s eta 0:00:00

# %%
#!pip install --upgrade --quiet pip -q
#!pip install --quiet git+https://github.com/huggingface/transformers.git -q
# !pip install TTS -qqq
# !!pip install pydub -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 938.0/938.0 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 66.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 85.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 46.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 21.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 34.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 33.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 68.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.9/252.9 kB 20.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 69.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 MB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.6 MB/s eta 0:00:00
#   Building wheel for encodec (setup.py) ... done
#   Building wheel for bnnumerizer (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for gruut-ipa (setup.py) ... done
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Building wheel for gruut (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.22.0 which is incompatible.
# cudf-cu12 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.0 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.5.3 which is incompatible.
# numexpr 2.10.1 requires numpy>=1.23.0, but you have numpy 1.22.0 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.22.0 which is incompatible.
# plotnine 0.12.4 requires numpy>=1.23.0, but you have numpy 1.22.0 which is incompatible.
# pywavelets 1.6.0 requires numpy<3,>=1.22.4, but you have numpy 1.22.0 which is incompatible.
# rmm-cu12 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.0 which is incompatible.
# statsmodels 0.14.2 requires numpy>=1.22.3, but you have numpy 1.22.0 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.22.0 which is incompatible.
# []

# %%
pip freeze > requirements.txt

# %% [markdown]
# ### STT

# %%
import torch
import os
import gc
from flask import Flask, render_template, request, jsonify, send_file, redirect, url_for
from werkzeug.utils import secure_filename
from faster_whisper import WhisperModel

# %%
model_size = "large-v3"
model = WhisperModel(model_size, device="cuda", compute_type="float16")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.39k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# vocabulary.json:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]

# %% [markdown]
# ### TTS

# %% [markdown]
# #### Bark

# %%
from transformers import BarkModel
from transformers import AutoProcessor
from IPython.display import Audio

# %%
model = BarkModel.from_pretrained("suno/bark")

device = "cuda:0" if torch.cuda.is_available() else "cpu"
model = model.to(device)

processor = AutoProcessor.from_pretrained("suno/bark")
# Out:
# config.json:   0%|          | 0.00/8.81k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.49G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# generation_config.json:   0%|          | 0.00/4.91k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/353 [00:00<?, ?B/s]
# speaker_embeddings_path.json:   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %% [markdown]
# #### CoquiTTS

# %%
from TTS.api import TTS
from IPython.display import Audio
from pydub import AudioSegment

# %%
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/TTS/api.py:70: UserWarning: `gpu` will be deprecated. Please use `tts.to(device)` instead.
#   warnings.warn("`gpu` will be deprecated. Please use `tts.to(device)` instead.")
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | > y
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100%|█████████▉| 1.86G/1.87G [00:27<00:00, 76.8MiB/s]
# 100%|██████████| 1.87G/1.87G [00:27<00:00, 67.6MiB/s]
# 100%|██████████| 4.37k/4.37k [00:00<00:00, 11.7kiB/s]
#
# 100%|██████████| 361k/361k [00:00<00:00, 939kiB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 47.7iB/s]
#  91%|█████████ | 7.03M/7.75M [00:00<00:00, 70.3MiB/s]
#  > Model's license - CPML
#  > Check https://coqui.ai/cpml.txt for more info.
#  > Using model: xtts
# 100%|██████████| 7.75M/7.75M [00:10<00:00, 70.3MiB/s]

# %% [markdown]
# ### LLM

# %%
#from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from langchain_huggingface import HuggingFacePipeline, HuggingFaceEndpoint
from langchain_community.llms import HuggingFaceEndpoint
from huggingface_hub import login
import pandas as pd

# %%
# Reemplaza 'your_token_here' con tu token real
hf_token = "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"

# Configura la variable de entorno para el token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = hf_token
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# Iniciar sesión utilizando el token
login(token=hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Define the repository ID for the Mistral 2b model
# repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

# Set up a Hugging Face Endpoint for Mistral 2b model
''' llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_new_tokens=512,
    #top_k=10,
    #top_p=0.95,
    #typical_p=0.95,
    temperature=0.8,
    #repetition_penalty=1.03,
    streaming=True,
    #model_kwargs={"device": "cuda:0"}
) '''

# Instancia del modelo usando Hugging Face
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1",
    task="text-generation",
    max_new_tokens=512,
    do_sample=False,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEndpoint` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEndpoint`.
#   warn_deprecated(
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### LLm + SQL

# %%
import pandas as pd
import sqlite3
from langchain_community.llms import HuggingFaceEndpoint
from langchain.utilities import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain
from huggingface_hub import login

# %%
# Reemplaza 'your_token_here' con tu token real
hf_token = "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"

# Configura la variable de entorno para el token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = hf_token
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# Iniciar sesión utilizando el token
login(token=hf_token)

# %%
df = pd.read_csv("/content/pob_gto.csv", encoding='utf-8')

# %%
# Connect to a new SQLite database
con = sqlite3.connect('my_data.db')

# Write the DataFrame to the SQL database
df.to_sql('pob_gto', con, if_exists='replace', index=False)

db = SQLDatabase.from_uri("sqlite:///my_data.db")

# %%
# Define the repository ID for the Mistral 2b model
repo_id = "mistralai/Mistral-7B-Instruct-v0.2"

# Set up a Hugging Face Endpoint for Mistral 2b model
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_new_tokens=512,
    #top_k=10,
    #top_p=0.95,
    #typical_p=0.95,
    temperature=0.8,
    #repetition_penalty=1.03,
    #streaming=True,
    #model_kwargs={"device": "cuda:0"}
)

# %%
db_chain = SQLDatabaseChain.from_llm(llm, db, verbose=True)

# %% [markdown]
# ### Run server

# %% [markdown]
# #### Base transcription with faster-whisper
#
# https://github.com/SYSTRAN/faster-whisper

# %%
@app.route('/')
def home():
    return render_template('index.html')

@app.route('/transcribe', methods=['POST'])
def transcribe():
    audio_file = request.files['audio']
    filename = secure_filename(audio_file.filename)
    audio_file.save(filename)

    segments, info = model.transcribe(filename, beam_size=5)

    transcript = "\n".join(segment.text for segment in segments)
    return transcript

if __name__ == '__main__':
    app.run()

# %% [markdown]
# #### Integration with LLM-SQL

# %%
from flask import Flask, render_template, request, jsonify
from werkzeug.utils import secure_filename
from faster_whisper import WhisperModel
import os

app = Flask(__name__, template_folder='templates', static_folder='static')
app.config['UPLOAD_FOLDER'] = 'uploads'
app.config['ALLOWED_EXTENSIONS'] = {'wav', 'mp3'}
app.config['MAX_CONTENT_LENGTH'] = 16 * 1024 * 1024  # 16 MB

model_size = "large-v3"
model = WhisperModel(model_size, device="cuda", compute_type="float16")

def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in app.config['ALLOWED_EXTENSIONS']

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/transcribe', methods=['POST'])
def transcribe():
    if 'audio' not in request.files:
        return jsonify({'error': 'No audio file part'}), 400
    audio_file = request.files['audio']
    if audio_file.filename == '' or not allowed_file(audio_file.filename):
        return jsonify({'error': 'Invalid file'}), 400

    filename = secure_filename(audio_file.filename)
    file_path = os.path.join(app.config['UPLOAD_FOLDER'], filename)
    audio_file.save(file_path)

    segments, info = model.transcribe(file_path, beam_size=5)
    os.remove(file_path)

    transcript = "\n".join(segment.text for segment in segments)
    return transcript

@app.route('/process', methods=['POST'])
def process():
    data = request.json
    question = data.get('question')

    Question = db_chain.invoke(question)

    if isinstance(Question, dict):
        answer = Question.get('result') or Question.get('Answer', 'No se encontró una respuesta.')
    else:
        resultado_texto = str(Question)
        inicio_answer = resultado_texto.find("Answer:") + len("Answer:")
        answer = resultado_texto[inicio_answer:].strip()

    return jsonify({'answer': answer})

if __name__ == '__main__':
    if not os.path.exists(app.config['UPLOAD_FOLDER']):
        os.makedirs(app.config['UPLOAD_FOLDER'])
    app.run()

# %% [markdown]
# #### Integration of LLM + SQL with error handling

# %%
from flask import Flask, render_template, request, jsonify
from werkzeug.utils import secure_filename
from faster_whisper import WhisperModel
import os

app = Flask(__name__, template_folder='templates', static_folder='static')
app.config['UPLOAD_FOLDER'] = 'uploads'
app.config['ALLOWED_EXTENSIONS'] = {'wav', 'mp3'}
app.config['MAX_CONTENT_LENGTH'] = 16 * 1024 * 1024  # 16 MB

def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in app.config['ALLOWED_EXTENSIONS']

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/transcribe', methods=['POST'])
def transcribe():
    if 'audio' not in request.files:
        return jsonify({'error': 'No audio file part'}), 400
    audio_file = request.files['audio']
    if audio_file.filename == '' or not allowed_file(audio_file.filename):
        return jsonify({'error': 'Invalid file'}), 400

    filename = secure_filename(audio_file.filename)
    file_path = os.path.join(app.config['UPLOAD_FOLDER'], filename)
    audio_file.save(file_path)

    segments, info = model.transcribe(file_path, beam_size=5)
    os.remove(file_path)

    transcript = "\n".join(segment.text for segment in segments)
    return transcript

@app.route('/process', methods=['POST'])
def process():
    data = request.json
    question = data.get('question')

    try:
        Question = db_chain.invoke(question)

        if isinstance(Question, dict):
            answer = Question.get('result') or Question.get('Answer', 'No se encontró una respuesta.')
        else:
            resultado_texto = str(Question)
            inicio_answer = resultado_texto.find("Answer:") + len("Answer:")
            answer = resultado_texto[inicio_answer:].strip()

            # Verificar si la respuesta es un mensaje de error
            if "OperationalError" in resultado_texto or "syntax error" in resultado_texto:
                answer = "No se pudo realizar esa consulta. Intente con otra."
    except Exception as e:
        # Manejo de errores generales
        answer = "No se pudo realizar esa consulta. Intente con otra."

    return jsonify({'answer': answer})

if __name__ == '__main__':
    if not os.path.exists(app.config['UPLOAD_FOLDER']):
        os.makedirs(app.config['UPLOAD_FOLDER'])
    app.run()

# %% [markdown]
# #### Integration of LLM + STT with error handling

# %%
app = Flask(__name__, template_folder='templates', static_folder='static')
app.config['UPLOAD_FOLDER'] = 'uploads'
app.config['ALLOWED_EXTENSIONS'] = {'wav', 'mp3'}
app.config['MAX_CONTENT_LENGTH'] = 16 * 1024 * 1024  # 16 MB

def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in app.config['ALLOWED_EXTENSIONS']

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/transcribe', methods=['POST'])
def transcribe():
    if 'audio' not in request.files:
        return jsonify({'error': 'No audio file part'}), 400
    audio_file = request.files['audio']
    if audio_file.filename == '' or not allowed_file(audio_file.filename):
        return jsonify({'error': 'Invalid file'}), 400

    filename = secure_filename(audio_file.filename)
    file_path = os.path.join(app.config['UPLOAD_FOLDER'], filename)
    audio_file.save(file_path)

    segments, info = model.transcribe(file_path, beam_size=5)
    os.remove(file_path)

    transcript = "\n".join(segment.text for segment in segments)
    return transcript

@app.route('/process', methods=['POST'])
def process():
    # Liberar memoria
    gc.collect()
    torch.cuda.empty_cache()

    # Obtener los datos del request
    data = request.json
    question = data.get('question')

    try:
        # Utilizar el modelo de lenguaje para generar la respuesta
        answer = llm.invoke(question)
        # print(answer)
    except Exception as e:
        # Manejo de errores generales
        answer = "No se pudo realizar esa consulta. Intente con otra."

    return jsonify({'answer': answer})

if __name__ == '__main__':
    if not os.path.exists(app.config['UPLOAD_FOLDER']):
        os.makedirs(app.config['UPLOAD_FOLDER'])
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 05:59:19] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 05:59:20] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 05:59:20] "GET /static/script.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 05:59:21] "GET /favicon.ico HTTP/1.1" 404 -

# %% [markdown]
# #### Integration of LLM + STT + TTS with error handling

# %%
app = Flask(__name__, template_folder='templates', static_folder='static')
app.config['UPLOAD_FOLDER'] = 'uploads'
app.config['ALLOWED_EXTENSIONS'] = {'wav', 'mp3'}
app.config['MAX_CONTENT_LENGTH'] = 16 * 1024 * 1024  # 16 MB

def allowed_file(filename):
    return '.' in filename and filename.rsplit('.', 1)[1].lower() in app.config['ALLOWED_EXTENSIONS']

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/transcribe', methods=['POST'])
def transcribe():
    if 'audio' not in request.files:
        return jsonify({'error': 'No audio file part'}), 400
    audio_file = request.files['audio']
    if audio_file.filename == '' or not allowed_file(audio_file.filename):
        return jsonify({'error': 'Invalid file'}), 400

    filename = secure_filename(audio_file.filename)
    file_path = os.path.join(app.config['UPLOAD_FOLDER'], filename)
    audio_file.save(file_path)

    segments, info = model.transcribe(file_path, beam_size=5)
    os.remove(file_path)

    transcript = "\n".join(segment.text for segment in segments)
    return transcript

@app.route('/process', methods=['POST'])
def process():
    gc.collect()
    torch.cuda.empty_cache()

    data = request.json
    question = data.get('question')

    try:
        answer = llm.invoke(question)
    except Exception as e:
        answer = "No se pudo realizar esa consulta. Intente con otra."

    return jsonify({'answer': answer})

def read_and_split_text(text, max_tokens):
    words = text.split()
    segments = []
    current_segment = []
    for word in words:
        test_segment = current_segment + [word]
        if len(' '.join(test_segment).split()) > max_tokens:
            segments.append(' '.join(current_segment))
            current_segment = [word]
        else:
            current_segment = test_segment
    if current_segment:
        segments.append(' '.join(current_segment))
    return segments

def synthesize_segments(segments, speaker_wav, language, output_prefix):
    file_paths = []
    for i, segment in enumerate(segments):
        file_path = f"{output_prefix}_part_{i}.wav"
        tts.tts_to_file(text=segment, file_path=file_path, speaker_wav=speaker_wav, language=language)
        file_paths.append(file_path)
    return file_paths

def combine_audio(segments, output_file, output_prefix):
    combined = AudioSegment.silent(duration=0)
    for i in range(len(segments)):
        audio = AudioSegment.from_wav(f"{output_prefix}_part_{i}.wav")
        combined += audio
    combined.export(output_file, format='wav')

def clean_up(file_paths):
    for file_path in file_paths:
        os.remove(file_path)

@app.route('/synthesize', methods=['POST'])
def synthesize():
    data = request.json
    text = data.get('text')
    speaker_wav = "/content/fer.wav"  # Ajusta la ruta según tu configuración
    language = "es"
    output_prefix = "output"
    final_output = "output.wav"
    max_tokens = 30

    segments = read_and_split_text(text, max_tokens)
    file_paths = synthesize_segments(segments, speaker_wav, language, output_prefix)
    combine_audio(segments, final_output, output_prefix)
    clean_up(file_paths)

    return send_file(final_output, mimetype="audio/wav")

if __name__ == '__main__':
    if not os.path.exists(app.config['UPLOAD_FOLDER']):
        os.makedirs(app.config['UPLOAD_FOLDER'])
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:10:20] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:10:21] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:10:21] "GET /static/script.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:10:22] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:10:36] "POST /transcribe HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:10:57] "POST /process HTTP/1.1" 200 -
#  > Text splitted to sentences.
# ['O sea, tú sabes que siempre he sido más de cine y música, pero me he metido en el mundo de la literatura y la verdad es que me está']
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:1466: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   resampled = torch.nn.functional.conv1d(waveform[:, None], kernel, stride=orig_freq)
#  > Processing time: 10.852095365524292
#  > Real-time factor: 0.8842632250702516
#  > Text splitted to sentences.
# ['gustando mucho.', 'Ahora estoy con una novela en la que la protagonista es una actriz, así que como tú eres actor...', 'Ya, ya...', 'Estoy en medio del rodaje de una']
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  > Processing time: 8.76670241355896
#  > Real-time factor: 0.5514703196862307
#  > Text splitted to sentences.
# ['serie y luego tengo dos pelis, así que no tengo mucho tiempo, pero bueno, cuéntame.', 'Claro, claro.', 'La protagonista es una actriz que se llama Ángela y vive en Madrid.']
#  > Processing time: 9.981134176254272
#  > Real-time factor: 0.5355780296947561
#  > Text splitted to sentences.
# ['Es una actriz muy famosa, pero también muy sola, y un día conoce a un hombre en un bar.', 'Él no sabe quién es ella, y ella no sabe nada']
#  > Processing time: 7.30701756477356
#  > Real-time factor: 0.6673282691486787
#  > Text splitted to sentences.
# ['de él.', 'Y tú, ¿has vivido algo así alguna vez?', 'No, la verdad es que no.', 'Yo soy actor, y cuando salgo a la calle la gente me reconoce, así']
#  > Processing time: 10.982151508331299
#  > Real-time factor: 0.5707790597156084
#  > Text splitted to sentences.
# ['que es difícil que no sepan quién soy.', 'Pero bueno, me gusta la idea de la historia.', '¿Y qué pasa después?', 'Bueno, pues después de conocerse en el bar, Ángela']
#  > Processing time: 6.765219688415527
#  > Real-time factor: 0.5183076708415415
#  > Text splitted to sentences.
# ['y este hombre, que se llama Carlos, empiezan a salir juntos.', 'Pero Ángela tiene miedo de que Carlos se enamore de ella por su fama y no por quién es']
#  > Processing time: 7.233575105667114
#  > Real-time factor: 0.5871581277239658
#  > Text splitted to sentences.
# ['en realidad.', 'Y tú, ¿cómo te has sentido tú en tus relaciones sentimentales?', '¿Te has sentido alguna vez como Ángela?', 'Bueno, no sé si me he sentido como Ángela, pero']
#  > Processing time: 8.146336555480957
#  > Real-time factor: 0.5294600106358326
#  > Text splitted to sentences.
# ['sí que es verdad que en alguna relación he tenido la sensación de que la otra persona se enamoraba más de mi fama que de mí.', 'Pero eso es algo']
#  > Processing time: 6.579108953475952
#  > Real-time factor: 0.6233214991412792
#  > Text splitted to sentences.
# ['que pasa en todos los ámbitos, no solo en el mundo del espectáculo.', 'Y tú, ¿cómo has gestionado eso?', 'Bueno, Ángela decide contarle la verdad a Carlos y decirle quién']
#  > Processing time: 7.682281017303467
#  > Real-time factor: 0.5418467437929956
#  > Text splitted to sentences.
# ['es en realidad.']
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:12:30] "POST /synthesize HTTP/1.1" 200 -
#  > Processing time: 1.2219860553741455
#  > Real-time factor: 0.8694112197018555
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:13:37] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:14:34] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:14:34] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:16:17] "POST /transcribe HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:16:33] "POST /transcribe HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:16:52] "POST /process HTTP/1.1" 200 -
#  > Text splitted to sentences.
# ['Si te preguntas qué significa che boludo, este artículo te interesará.', 'Este término es bastante popular en la Argentina, y aunque no es ofensivo, tampoco es nada cariñoso.', 'Sigue leyendo']
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:1466: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   resampled = torch.nn.functional.conv1d(waveform[:, None], kernel, stride=orig_freq)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  > Processing time: 8.958683013916016
#  > Real-time factor: 0.5727759233845052
#  > Text splitted to sentences.
# ['y descubre el significado de che boludo y cómo usarlo.', '## Qué significa che boludo El término che boludo es una interjección muy usada en el idioma argentino, especialmente por']
#  > Processing time: 11.266334533691406
#  > Real-time factor: 0.5576617081834448
#  > Text splitted to sentences.
# ['los jóvenes.', 'En sí, “che” es un término que se usa para llamar la atención de alguien o simplemente para empezar a hablar.', 'Se podría decir que es un sinónimo']
#  > Processing time: 6.94071626663208
#  > Real-time factor: 0.5035627588814074
#  > Text splitted to sentences.
# ['de “oye” o “eh”, aunque no tiene una traducción directa.', 'Por otra parte, “boludo” se utiliza para referirse a una persona tonta o sin conocimientos.', 'Es una palabra bastante fuerte,']
#  > Processing time: 9.830119132995605
#  > Real-time factor: 0.5610275781736683
#  > Text splitted to sentences.
# ['así que no es muy recomendable utilizarla, a menos que quieras ofender a alguien.', 'De esta forma, “che boludo” es un término usado para llamar la atención de alguien, especialmente']
#  > Processing time: 10.090782165527344
#  > Real-time factor: 0.561419425590124
#  > Text splitted to sentences.
# ['si se quiere molestar o ofender.', 'Ejemplos: - Che boludo, ¿qué estás haciendo?', '- ¿Por qué te comportas como un boludo?', '## Origen de la expresión che boludo No se']
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:797: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv_transpose1d(
#  > Processing time: 9.498593807220459
#  > Real-time factor: 0.5410088275159405
#  > Text splitted to sentences.
# ['sabe a ciencia cierta cuál es el origen del término che boludo, aunque se cree que proviene de la palabra “boleto”, que significa “tonto”.', 'Por otra parte, “che” proviene del']
#  > Processing time: 9.358278036117554
#  > Real-time factor: 0.5261025095261689
#  > Text splitted to sentences.
# ['lunfardo, un argot propio de los grupos de delincuentes en Argentina.', 'De este modo, “che boludo” podría traducirse como “tonto” o “imbécil”.', 'A pesar de que “che boludo” no es']
#  > Processing time: 9.881657600402832
#  > Real-time factor: 0.5658436606371859
#  > Text splitted to sentences.
# ['un término amistoso, sí es muy usado por los argentinos para llamar la atención de alguien o burlarse de']
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:18:21] "POST /synthesize HTTP/1.1" 200 -
#  > Processing time: 4.636724472045898
#  > Real-time factor: 0.49917865112399445
#  > Text splitted to sentences.
# ['¿Me puedes decir qué significa che boludo?']
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:21:34] "POST /synthesize HTTP/1.1" 200 -
#  > Processing time: 1.8282904624938965
#  > Real-time factor: 0.541037748255186
#  > Text splitted to sentences.
# ['Sí, hola, ¿qué tal?', 'Sí, un, dos, tres...']
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:21:46] "POST /synthesize HTTP/1.1" 200 -
#  > Processing time: 5.593461751937866
#  > Real-time factor: 0.648317029174884
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:22:43] "POST /process HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:23:39] "POST /process HTTP/1.1" 200 -
#  > Text splitted to sentences.
# ['en 10 palabras dime el significado de boludo']
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:1466: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   resampled = torch.nn.functional.conv1d(waveform[:, None], kernel, stride=orig_freq)
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:24:04] "POST /synthesize HTTP/1.1" 200 -
#  > Processing time: 1.7981607913970947
#  > Real-time factor: 0.5491004521702019
#  > Text splitted to sentences.
# ['que te parece si me explico un poquito mas, boludo es una palabra del lunfardo (un argot rioplatense) que significa tonto, tarado, estúpido, etc. en definitiva, alguien que no tiene']
#  > Processing time: 7.9625465869903564
#  > Real-time factor: 0.5002226610382497
#  > Text splitted to sentences.
# ['mucho sentido común o que hace cosas bastante estúpidas.', 'esta palabra tiene un tono muy informal y se usa principalmente entre personas cercanas.', 'en resumen, boludo es una palabra muy']
#  > Processing time: 10.34206748008728
#  > Real-time factor: 0.5552912980089331
#  > Text splitted to sentences.
# ['coloquial en la Argentina y Uruguay, que significa tonto, tarado o estúpido.', 'se usa sobre todo en situaciones informales y entre personas cercanas.']
# INFO:werkzeug:127.0.0.1 - - [28/Jun/2024 06:24:35] "POST /synthesize HTTP/1.1" 200 -
#  > Processing time: 7.998691558837891
#  > Real-time factor: 0.5887830789725172

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))
# Out:
# https://64z8lruszfg-496ff2e9c6d22116-5000-colab.googleusercontent.com/
